# %% [markdown]
# <a href="https://colab.research.google.com/github/yuyuliang660-jpg/LIANG-XIANYU/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# MNIST 数据集加载
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# 打印 train_images[6000] 图像
plt.figure(figsize=(8, 8))
plt.imshow(train_images[6000], cmap='gray')  # MNIST是灰度图，使用灰度色彩映射
plt.title(f'Label: {train_labels[6000]}')  # 显示对应的标签
plt.axis('off')  # 隐藏坐标轴
plt.colorbar()  # 显示颜色条
plt.show()

plt.imshow(train_images[6000])
